# %%
import pandas as pd
import random

# %%
zones = pd.read_csv("zones.csv")
zones = zones.set_index("PID")
zones.shape
# Out:
# (203, 2)

# %%
roster = pd.read_csv("roster.csv")
roster = roster.set_index("ID")
roster.shape
# Out:
# (203, 4)
